# %% [markdown]
# ## “Las 20 Peliculas y series mayor vistas en Disney Plus 2021” 🎬

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importación de nuestro CSV ✅

# %%
ds_disney_p = pd.read_csv('./disney_plus_titles.csv')
ds_disney_p.head(2)
# Out:
#     type                                             title  \
# 0  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1  Movie                            Ernest Saves Christmas
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
#
#           date_added  release_year rating duration          listed_in  \
# 0  November 26, 2021          2016   TV-G       23  Animation, Family
# 1  November 26, 2021          1988     PG       91             Comedy
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...

# %%
ds_disney_p_Es= pd.read_csv('./disney_plus_titles.csv', sep=',', header=0, names=['Tipo', 'Titulo', 'Director', 'Reparto', 'País',
       'Fehca en Disney+','Estreno', 'Transmición', 'Duración (Minutos)','Clasifiación','Descripción'],index_col=0)
ds_disney_p_Es_vi = ds_disney_p_Es.reset_index(drop=False)
ds_disney_p_Es_vi.head(2)
# Out:
#     Tipo                                            Titulo  \
# 0  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1  Movie                            Ernest Saves Christmas
#
#                             Director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
#
#                                              Reparto           País  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
#
#     Fehca en Disney+  Estreno Transmición Duración (Minutos)  \
# 0  November 26, 2021     2016        TV-G                 23
# 1  November 26, 2021     1988          PG                 91
#
#         Clasifiación                                        Descripción
# 0  Animation, Family   Join Mickey and the gang as they duck the halls!
# 1             Comedy  Santa Claus passes his magic bag to a new St. ...

# %% [markdown]
# * Recopilación de los 20 Titulos más vistos ✅

# %%
df_disney_p_Es_20= ds_disney_p_Es_vi.head(20)
df_disney_p_Es_20.head(2)
# Out:
#     Tipo                                            Titulo  \
# 0  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1  Movie                            Ernest Saves Christmas
#
#                             Director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
#
#                                              Reparto           País  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
#
#     Fehca en Disney+  Estreno Transmición Duración (Minutos)  \
# 0  November 26, 2021     2016        TV-G                 23
# 1  November 26, 2021     1988          PG                 91
#
#         Clasifiación                                        Descripción
# 0  Animation, Family   Join Mickey and the gang as they duck the halls!
# 1             Comedy  Santa Claus passes his magic bag to a new St. ...

# %% [markdown]
# ### Ahora que ya tenemos nuestro DF listo,**resolveremos una serie de preguntas** que nos ayudará a nuestro **Analisis de Datos**
# **1.** ¿De los titulos más vistos en Disney+ 2021, qué tipo de **contendio** es? 🧐

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_disney_p_Es_20, x='Tipo', y='Titulo');
plt.show()

# %% [markdown]
# 2. Ademas de su **tipo** quiero saber ¿Donde fue **producido** este contenido? 🌎

# %%
plt.figure(figsize=(8,6.2))
plt.title('Relación entre los 20 Titulos más vistos en Disney+ y su tipo ')
sns.swarmplot(data = df_disney_p_Es_20, x ='Tipo',y = 'Titulo', hue= 'País', dodge= False, marker = 'p', size=10);
plt.legend(bbox_to_anchor=(0.9, 0.9), loc='upper left', bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# **3.** Excelente, pero quiero tener una **ayuda visual** que me permita entnder mejor **las categorias más vistas en este DF**

# %% [markdown]
# * ### Representacion en una grafica de Pastel 🍰

# %%
# Obtener el recuento de cada categoría
counts = df_disney_p_Es_20['Tipo'].value_counts()

# Creamos una lista de etiquetas, valores & Colores
labels = counts.index
values = counts.values
colors = ['#3D8361', '#C7E8CA']

# %%
# Creando un gráfico de pastel utilizando Matplotlib
plt.pie(values, labels=labels, autopct='%1.1f%%', colors= colors)

# Aspecto del gráfico de pastel

title_font = {'fontsize': 23, 'fontweight': 'bold', 'color': '#454545'}
plt.title("Distribución de Categorías", fontdict=title_font)

plt.axis('equal')
plt.show()

# %%
df_disney_p_Es_20.head(2)
# Out:
#     Tipo                                            Titulo  \
# 0  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1  Movie                            Ernest Saves Christmas
#
#                             Director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
#
#                                              Reparto           País  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
#
#     Fehca en Disney+  Estreno Transmición Duración (Minutos)  \
# 0  November 26, 2021     2016        TV-G                 23
# 1  November 26, 2021     1988          PG                 91
#
#         Clasifiación                                        Descripción
# 0  Animation, Family   Join Mickey and the gang as they duck the halls!
# 1             Comedy  Santa Claus passes his magic bag to a new St. ...

# %% [markdown]
# **4**. Ahora me interesa saber ¿**Qué relación** existe entre el **año de estreno** y **su duración** de este contenido?

# %%
# Convertimos la columna 'Duración (Minutos)' a tipo numérico
df_disney_p_Es_20['Duración (Minutos)'] = pd.to_numeric(df_disney_p_Es_20['Duración (Minutos)'])

# Ordenamos el DF de la columna 'Duración (Minutos)' de menor a mayor
df_disney_p_Es_20_sorted = df_disney_p_Es_20.sort_values('Duración (Minutos)', ascending=True)

plt.figure(figsize=(8, 6))
plt.title('Relación entre Año de Estreno vs Duración')
sns.scatterplot(data=df_disney_p_Es_20_sorted, x='Estreno', y='Duración (Minutos)', hue='Titulo', palette='colorblind');
plt.xlabel('Año de Estreno')
plt.ylabel('Duración en Minutos')
plt.legend(bbox_to_anchor=(0.9, 0.9), title='Titulo',loc='upper left', bbox_transform=plt.gcf().transFigure)
plt.show()
# Out:
# /tmp/ipykernel_351/465958314.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_disney_p_Es_20['Duración (Minutos)'] = pd.to_numeric(df_disney_p_Es_20['Duración (Minutos)'])

# %% [markdown]
# **5**. Por ultimo me interesa saber ¿Cual es la **clasifiacion es más exitosa** en este DF? R = **Animation, Comedy, Family**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df_disney_p_Es_20, x='Tipo', hue='Clasifiación')

plt.title('Distribución de Clasificación por Tipo de Contenido')
plt.xlabel('Tipo de Contenido')
plt.ylabel('Cantidad')
# plt.legend(title='Clasificación')
plt.legend(bbox_to_anchor=(0.9, 0.9), title='Clasificación',loc='upper left', bbox_transform=plt.gcf().transFigure)
plt.show()
